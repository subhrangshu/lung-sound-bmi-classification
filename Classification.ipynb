# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pickle
import os
import matplotlib
import time

from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import RadiusNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import ExtraTreeClassifier

from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import *
from sklearn import decomposition
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
#import keras
#from keras.models import Sequential
#from keras.layers import LSTM, Dropout, Activation, Flatten, Dense, Reshape
#from keras.layers import Conv1D, MaxPooling1D

# %%
fulldata = pd.read_csv('../Data/ICBHI Processed Data/Filtered_Processed_Labelled_Data.csv')
fulldata = fulldata.sample(frac=1).reset_index(drop=True)
fulldata = fulldata.drop('Unnamed: 0', axis=1)
fulldata = fulldata.drop('Subject ID', axis=1)
fulldata
# Out:
#                 Ar        Al        Pl        Pr        Lr     Category
# 0        -0.273319  0.137984 -0.005085  0.010916 -0.119183   Overweight
# 1        -0.104099 -0.106079  0.029562  0.040893  0.114489   Overweight
# 2         0.009603 -0.113798  0.105614 -0.047210 -0.125987   Overweight
# 3         0.295804  0.283986  0.253733  0.439246  0.009816  Underweight
# 4         0.330697  0.794443  0.316807 -0.296686 -0.270121   Overweight
# ...            ...       ...       ...       ...       ...          ...
# 19232054 -0.543085  1.000000 -0.096748  0.193439  0.151960   Overweight
# 19232055  0.210454 -0.197938 -0.123697 -0.122734 -0.199600       Normal
# 19232056 -0.074065  0.269674  0.075194 -0.087768 -0.071834       Normal
# 19232057 -0.071383  0.056858 -0.197763  0.077040 -0.190004   Overweight
# 19232058  0.560867 -0.029184  0.181751 -0.034642  0.531031   Overweight
#
# [19232059 rows x 6 columns]

# %%
classificationdata = pd.read_csv('../Data/ICBHI Processed Data/Classification_ready.csv')
classificationdata = classificationdata.sample(frac=1).reset_index(drop=True)
classificationdata = classificationdata.drop(['Unnamed: 0'], axis=1)
classificationdata
# Out:
#              Ar        Al        Pl        Pr        Lr     Category
# 0      0.118021  0.180190  0.380782  0.304179  0.212196  Underweight
# 1      0.207750  0.149704  0.289780  0.151200  0.195139       Normal
# 2      0.194788  0.212969  0.222978  0.151624  0.165799       Normal
# 3      0.138890  0.171471  0.425536  0.304348  0.218476  Underweight
# 4      0.229526  0.193909  0.293638  0.187398  0.132942       Normal
# ...         ...       ...       ...       ...       ...          ...
# 26455  0.120628  0.207031  0.458501  0.326273  0.249310  Underweight
# 26456  0.212387  0.212911  0.198500  0.197493  0.202631   Overweight
# 26457  0.093438  0.243220  0.431442  0.303040  0.204735  Underweight
# 26458  0.141375  0.248101  0.271806  0.184625  0.095752       Normal
# 26459  0.185845  0.224016  0.172500  0.228219  0.177787   Overweight
#
# [26460 rows x 6 columns]

# %%
# Full Data

# %%
fulldata = fulldata.sample(frac=1).reset_index(drop=True)
fulldatatrain = fulldata[:200000]
fulldatatest = fulldata[200000:264600]
X_train = fulldatatrain[['Ar','Al','Pl','Pr','Lr']]
y_train = fulldatatrain[['Category']]
X_test = fulldatatest[['Ar','Al','Pl','Pr','Lr']]
y_test = fulldatatest[['Category']]

#SVMmodel = SVC(gamma='auto')
#a = time.time()
#SVMmodel = SVMmodel.fit(X_train, y_train)
#b = time.time()
#print('Train time for SVM: ' + str((b-a)*1000))


KNNmodel = KNeighborsClassifier(n_neighbors=1)
a = time.time()
KNNmodel = KNNmodel.fit(X_train, y_train)
b = time.time()
print('Train time for KNN: ' + str((b-a)*1000))


#RNNmodel = RadiusNeighborsClassifier(radius=1.085)
#a = time.time()
#RNNmodel = RNNmodel.fit(X_train, y_train)
#b = time.time()
#print('Train time for RNN: ' + str((b-a)*1000))


DTCmodel = DecisionTreeClassifier()
a = time.time()
DTCmodel = DTCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for DTC: ' + str((b-a)*1000))


RFCmodel = RandomForestClassifier(n_estimators=100)
a = time.time()
RFCmodel = RFCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for RFC: ' + str((b-a)*1000))


ETCmodel = ExtraTreeClassifier()
a = time.time()
ETCmodel = ETCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for ETC: ' + str((b-a)*1000))


GNBmodel = GaussianNB()
a = time.time()
GNBmodel = GNBmodel.fit(X_train,y_train)
b = time.time()
print('Train time for GNB: ' + str((b-a)*1000))


BNBmodel = BernoulliNB()
a = time.time()
BNBmodel = BNBmodel.fit(X_train,y_train)
b = time.time()
print('Train time for BNB: ' + str((b-a)*1000))


LRGmodel = LogisticRegression(solver='lbfgs')
a = time.time()
LRGmodel = LRGmodel.fit(X_train, y_train)
b = time.time()
print('Train time for LRG: ' + str((b-a)*1000))


LDAmodel = LinearDiscriminantAnalysis()
a = time.time()
LDAmodel = LDAmodel.fit(X_train, y_train)
b = time.time()
print('Train time for LDA: ' + str((b-a)*1000))


MLPmodel = MLPClassifier(solver='lbfgs')
a = time.time()
MLPmodel = MLPmodel.fit(X_train, y_train)
b = time.time()
print('Train time for MLP: ' + str((b-a)*1000))


#a = time.time()
#SVMprediction = SVMmodel.predict(X_test)
#b = time.time()
#print('Prediction time for SVM: ' + str((b-a)*1000))

a = time.time()
KNNprediction = KNNmodel.predict(X_test)
b = time.time()
print('Prediction time for KNN: ' + str((b-a)*1000))

#a = time.time()
#RNNprediction = RNNmodel.predict(X_test)
#b = time.time()
#print('Prediction time for SVM: ' + str((b-a)*1000))

a = time.time()
DTCprediction = DTCmodel.predict(X_test)
b = time.time()
print('Prediction time for DTC: ' + str((b-a)*1000))

a = time.time()
RFCprediction = RFCmodel.predict(X_test)
b = time.time()
print('Prediction time for RFC: ' + str((b-a)*1000))

a = time.time()
ETCprediction = ETCmodel.predict(X_test)
b = time.time()
print('Prediction time for ETC: ' + str((b-a)*1000))

a = time.time()
GNBprediction = GNBmodel.predict(X_test)
b = time.time()
print('Prediction time for GNB: ' + str((b-a)*1000))

a = time.time()
BNBprediction = BNBmodel.predict(X_test)
b = time.time()
print('Prediction time for BNB: ' + str((b-a)*1000))

a = time.time()
LRGprediction = LRGmodel.predict(X_test)
b = time.time()
print('Prediction time for LRG: ' + str((b-a)*1000))

a = time.time()
LDAprediction = LDAmodel.predict(X_test)
b = time.time()
print('Prediction time for LDA: ' + str((b-a)*1000))

a = time.time()
MLPprediction = MLPmodel.predict(X_test)
b = time.time()
print('Prediction time for MLP: ' + str((b-a)*1000))

#print("Accuracy of the SVM model for this data: " + str(accuracy_score(SVMprediction, y_test)*100))
print("Accuracy of the KNN model for this data: " + str(accuracy_score(KNNprediction, y_test)*100))
#print("Accuracy of the RNN model for this data: " + str(accuracy_score(RNNprediction, y_test)*100))
print("Accuracy of the DTC model for this data: " + str(accuracy_score(DTCprediction, y_test)*100))
print("Accuracy of the RFC model for this data: " + str(accuracy_score(RFCprediction, y_test)*100))
print("Accuracy of the ETC model for this data: " + str(accuracy_score(ETCprediction, y_test)*100))
print("Accuracy of the GNB model for this data: " + str(accuracy_score(GNBprediction, y_test)*100))
print("Accuracy of the BNB model for this data: " + str(accuracy_score(BNBprediction, y_test)*100))
print("Accuracy of the LRG model for this data: " + str(accuracy_score(LRGprediction, y_test)*100))
print("Accuracy of the LDA model for this data: " + str(accuracy_score(LDAprediction, y_test)*100))
print("Accuracy of the MLP model for this data: " + str(accuracy_score(MLPprediction, y_test)*100))


#print("Precision of the SVM model for this data: " + str(np.mean(precision_score(SVMprediction, y_test, average=None))))
print("Precision of the KNN model for this data: " + str(np.mean(precision_score(KNNprediction, y_test, average=None))))
#print("Precision of the RNN model for this data: " + str(np.mean(precision_score(RNNprediction, y_test, average=None))))
print("Precision of the DTC model for this data: " + str(np.mean(precision_score(DTCprediction, y_test, average=None))))
print("Precision of the RFC model for this data: " + str(np.mean(precision_score(RFCprediction, y_test, average=None))))
print("Precision of the ETC model for this data: " + str(np.mean(precision_score(ETCprediction, y_test, average=None))))
print("Precision of the GNB model for this data: " + str(np.mean(precision_score(GNBprediction, y_test, average=None))))
print("Precision of the BNB model for this data: " + str(np.mean(precision_score(BNBprediction, y_test, average=None))))
print("Precision of the LRG model for this data: " + str(np.mean(precision_score(LRGprediction, y_test, average=None))))
print("Precision of the LDA model for this data: " + str(np.mean(precision_score(LDAprediction, y_test, average=None))))
print("Precision of the MLP model for this data: " + str(np.mean(precision_score(MLPprediction, y_test, average=None))))



#print("Recall of the SVM model for this data: " + str(np.mean(recall_score(SVMprediction, y_test, average=None))))
print("Recall of the KNN model for this data: " + str(np.mean(recall_score(KNNprediction, y_test, average=None))))
#print("Recall of the RNN model for this data: " + str(np.mean(recall_score(RNNprediction, y_test, average=None))))
print("Recall of the DTC model for this data: " + str(np.mean(recall_score(DTCprediction, y_test, average=None))))
print("Recall of the RFC model for this data: " + str(np.mean(recall_score(RFCprediction, y_test, average=None))))
print("Recall of the ETC model for this data: " + str(np.mean(recall_score(ETCprediction, y_test, average=None))))
print("Recall of the GNB model for this data: " + str(np.mean(recall_score(GNBprediction, y_test, average=None))))
print("Recall of the BNB model for this data: " + str(np.mean(recall_score(BNBprediction, y_test, average=None))))
print("Recall of the LRG model for this data: " + str(np.mean(recall_score(LRGprediction, y_test, average=None))))
print("Recall of the LDA model for this data: " + str(np.mean(recall_score(LDAprediction, y_test, average=None))))
print("Recall of the MLP model for this data: " + str(np.mean(recall_score(MLPprediction, y_test, average=None))))


#print("F1_score of the SVM model for this data: " + str(np.mean(f1_score(SVMprediction, y_test, average=None))))
print("F1_score of the KNN model for this data: " + str(np.mean(f1_score(KNNprediction, y_test, average=None))))
#print("F1_score of the RNN model for this data: " + str(np.mean(f1_score(RNNprediction, y_test, average=None))))
print("F1_score of the DTC model for this data: " + str(np.mean(f1_score(DTCprediction, y_test, average=None))))
print("F1_score of the RFC model for this data: " + str(np.mean(f1_score(RFCprediction, y_test, average=None))))
print("F1_score of the ETC model for this data: " + str(np.mean(f1_score(ETCprediction, y_test, average=None))))
print("F1_score of the GNB model for this data: " + str(np.mean(f1_score(GNBprediction, y_test, average=None))))
print("F1_score of the BNB model for this data: " + str(np.mean(f1_score(BNBprediction, y_test, average=None))))
print("F1_score of the LRG model for this data: " + str(np.mean(f1_score(LRGprediction, y_test, average=None))))
print("F1_score of the LDA model for this data: " + str(np.mean(f1_score(LDAprediction, y_test, average=None))))
print("F1_score of the MLP model for this data: " + str(np.mean(f1_score(MLPprediction, y_test, average=None))))


#print("Jaccard_score of the SVM model for this data: " + str(np.mean(jaccard_score(SVMprediction, y_test, average=None))))
print("Jaccard_score of the KNN model for this data: " + str(np.mean(jaccard_score(KNNprediction, y_test, average=None))))
#print("Jaccard_score of the RNN model for this data: " + str(np.mean(jaccard_score(RNNprediction, y_test, average=None))))
print("Jaccard_score of the DTC model for this data: " + str(np.mean(jaccard_score(DTCprediction, y_test, average=None))))
print("Jaccard_score of the RFC model for this data: " + str(np.mean(jaccard_score(RFCprediction, y_test, average=None))))
print("Jaccard_score of the ETC model for this data: " + str(np.mean(jaccard_score(ETCprediction, y_test, average=None))))
print("Jaccard_score of the GNB model for this data: " + str(np.mean(jaccard_score(GNBprediction, y_test, average=None))))
print("Jaccard_score of the BNB model for this data: " + str(np.mean(jaccard_score(BNBprediction, y_test, average=None))))
print("Jaccard_score of the LRG model for this data: " + str(np.mean(jaccard_score(LRGprediction, y_test, average=None))))
print("Jaccard_score of the LDA model for this data: " + str(np.mean(jaccard_score(LDAprediction, y_test, average=None))))
print("Jaccard_score of the MLP model for this data: " + str(np.mean(jaccard_score(MLPprediction, y_test, average=None))))


#print("Kohen_Kappa_score of the SVM model for this data: " + str(np.mean(cohen_kappa_score(SVMprediction, y_test))))
print("Kohen_Kappa_score of the KNN model for this data: " + str(np.mean(cohen_kappa_score(KNNprediction, y_test))))
#print("Kohen_Kappa_score of the RNN model for this data: " + str(np.mean(cohen_kappa_score(RNNprediction, y_test))))
print("Kohen_Kappa_score of the DTC model for this data: " + str(np.mean(cohen_kappa_score(DTCprediction, y_test))))
print("Kohen_Kappa_score of the RFC model for this data: " + str(np.mean(cohen_kappa_score(RFCprediction, y_test))))
print("Kohen_Kappa_score of the ETC model for this data: " + str(np.mean(cohen_kappa_score(ETCprediction, y_test))))
print("Kohen_Kappa_score of the GNB model for this data: " + str(np.mean(cohen_kappa_score(GNBprediction, y_test))))
print("Kohen_Kappa_score of the BNB model for this data: " + str(np.mean(cohen_kappa_score(BNBprediction, y_test))))
print("Kohen_Kappa_score of the LRG model for this data: " + str(np.mean(cohen_kappa_score(LRGprediction, y_test))))
print("Kohen_Kappa_score of the LDA model for this data: " + str(np.mean(cohen_kappa_score(LDAprediction, y_test))))
print("Kohen_Kappa_score of the MLP model for this data: " + str(np.mean(cohen_kappa_score(MLPprediction, y_test))))


#print("Hamming_Loss of the SVM model for this data: " + str(np.mean(hamming_loss(SVMprediction, y_test))))
print("Hamming_Loss of the KNN model for this data: " + str(np.mean(hamming_loss(KNNprediction, y_test))))
#print("Hamming_Loss of the RNN model for this data: " + str(np.mean(hamming_loss(RNNprediction, y_test))))
print("Hamming_Loss of the DTC model for this data: " + str(np.mean(hamming_loss(DTCprediction, y_test))))
print("Hamming_Loss of the RFC model for this data: " + str(np.mean(hamming_loss(RFCprediction, y_test))))
print("Hamming_Loss of the ETC model for this data: " + str(np.mean(hamming_loss(ETCprediction, y_test))))
print("Hamming_Loss of the GNB model for this data: " + str(np.mean(hamming_loss(GNBprediction, y_test))))
print("Hamming_Loss of the BNB model for this data: " + str(np.mean(hamming_loss(BNBprediction, y_test))))
print("Hamming_Loss of the LRG model for this data: " + str(np.mean(hamming_loss(LRGprediction, y_test))))
print("Hamming_Loss of the LDA model for this data: " + str(np.mean(hamming_loss(LDAprediction, y_test))))
print("Hamming_Loss of the MLP model for this data: " + str(np.mean(hamming_loss(MLPprediction, y_test))))


#print("Matthews_corrcoef of the SVM model for this data: " + str(np.mean(matthews_corrcoef(SVMprediction, y_test))))
print("Matthews_corrcoef of the KNN model for this data: " + str(np.mean(matthews_corrcoef(KNNprediction, y_test))))
#print("Matthews_corrcoef of the RNN model for this data: " + str(np.mean(matthews_corrcoef(RNNprediction, y_test))))
print("Matthews_corrcoef of the DTC model for this data: " + str(np.mean(matthews_corrcoef(DTCprediction, y_test))))
print("Matthews_corrcoef of the RFC model for this data: " + str(np.mean(matthews_corrcoef(RFCprediction, y_test))))
print("Matthews_corrcoef of the ETC model for this data: " + str(np.mean(matthews_corrcoef(ETCprediction, y_test))))
print("Matthews_corrcoef of the GNB model for this data: " + str(np.mean(matthews_corrcoef(GNBprediction, y_test))))
print("Matthews_corrcoef of the BNB model for this data: " + str(np.mean(matthews_corrcoef(BNBprediction, y_test))))
print("Matthews_corrcoef of the LRG model for this data: " + str(np.mean(matthews_corrcoef(LRGprediction, y_test))))
print("Matthews_corrcoef of the LDA model for this data: " + str(np.mean(matthews_corrcoef(LDAprediction, y_test))))
print("Matthews_corrcoef of the MLP model for this data: " + str(np.mean(matthews_corrcoef(MLPprediction, y_test))))
# Out:
# /home/subhrangshu/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Train time for KNN: 336.99512481689453
# Train time for DTC: 2316.8551921844482
# /tmp/ipykernel_7932/1582871775.py:39: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFCmodel = RFCmodel.fit(X_train, y_train)
# Train time for RFC: 59636.96908950806
# Train time for ETC: 346.83990478515625
# /home/subhrangshu/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
# Classification Data

# %%
classificationdata = classificationdata.sample(frac=1).reset_index(drop=True)
classificationtrain = classificationdata[:12000]
classificationtest = classificationdata[12000:]
X_train = classificationtrain[['Ar','Al','Pl','Pr','Lr']]
y_train = classificationtrain[['Category']]
X_test = classificationtest[['Ar','Al','Pl','Pr','Lr']]
y_test = classificationtest[['Category']]

#SVMmodel = SVC(gamma='auto')
#a = time.time()
#SVMmodel = SVMmodel.fit(X_train, y_train)
#b = time.time()
#print('Train time for SVM: ' + str((b-a)*1000))


KNNmodel = KNeighborsClassifier(n_neighbors=1)
a = time.time()
KNNmodel = KNNmodel.fit(X_train, y_train)
b = time.time()
print('Train time for KNN: ' + str((b-a)*1000))


#RNNmodel = RadiusNeighborsClassifier(radius=1.085)
#a = time.time()
#RNNmodel = RNNmodel.fit(X_train, y_train)
#b = time.time()
#print('Train time for RNN: ' + str((b-a)*1000))


DTCmodel = DecisionTreeClassifier()
a = time.time()
DTCmodel = DTCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for DTC: ' + str((b-a)*1000))


RFCmodel = RandomForestClassifier(n_estimators=100)
a = time.time()
RFCmodel = RFCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for RFC: ' + str((b-a)*1000))


ETCmodel = ExtraTreeClassifier()
a = time.time()
ETCmodel = ETCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for ETC: ' + str((b-a)*1000))


GNBmodel = GaussianNB()
a = time.time()
GNBmodel = GNBmodel.fit(X_train,y_train)
b = time.time()
print('Train time for GNB: ' + str((b-a)*1000))


BNBmodel = BernoulliNB()
a = time.time()
BNBmodel = BNBmodel.fit(X_train,y_train)
b = time.time()
print('Train time for BNB: ' + str((b-a)*1000))


LRGmodel = LogisticRegression(solver='lbfgs')
a = time.time()
LRGmodel = LRGmodel.fit(X_train, y_train)
b = time.time()
print('Train time for LRG: ' + str((b-a)*1000))


LDAmodel = LinearDiscriminantAnalysis()
a = time.time()
LDAmodel = LDAmodel.fit(X_train, y_train)
b = time.time()
print('Train time for LDA: ' + str((b-a)*1000))


MLPmodel = MLPClassifier(solver='lbfgs')
a = time.time()
MLPmodel = MLPmodel.fit(X_train, y_train)
b = time.time()
print('Train time for MLP: ' + str((b-a)*1000))


#a = time.time()
#SVMprediction = SVMmodel.predict(X_test)
#b = time.time()
#print('Prediction time for SVM: ' + str((b-a)*1000))

a = time.time()
KNNprediction = KNNmodel.predict(X_test)
b = time.time()
print('Prediction time for KNN: ' + str((b-a)*1000))

#a = time.time()
#RNNprediction = RNNmodel.predict(X_test)
#b = time.time()
#print('Prediction time for SVM: ' + str((b-a)*1000))

a = time.time()
DTCprediction = DTCmodel.predict(X_test)
b = time.time()
print('Prediction time for DTC: ' + str((b-a)*1000))

a = time.time()
RFCprediction = RFCmodel.predict(X_test)
b = time.time()
print('Prediction time for RFC: ' + str((b-a)*1000))

a = time.time()
ETCprediction = ETCmodel.predict(X_test)
b = time.time()
print('Prediction time for ETC: ' + str((b-a)*1000))

a = time.time()
GNBprediction = GNBmodel.predict(X_test)
b = time.time()
print('Prediction time for GNB: ' + str((b-a)*1000))

a = time.time()
BNBprediction = BNBmodel.predict(X_test)
b = time.time()
print('Prediction time for BNB: ' + str((b-a)*1000))

a = time.time()
LRGprediction = LRGmodel.predict(X_test)
b = time.time()
print('Prediction time for LRG: ' + str((b-a)*1000))

a = time.time()
LDAprediction = LDAmodel.predict(X_test)
b = time.time()
print('Prediction time for LDA: ' + str((b-a)*1000))

a = time.time()
MLPprediction = MLPmodel.predict(X_test)
b = time.time()
print('Prediction time for MLP: ' + str((b-a)*1000))

#print("Accuracy of the SVM model for this data: " + str(accuracy_score(SVMprediction, y_test)*100))
print("Accuracy of the KNN model for this data: " + str(accuracy_score(KNNprediction, y_test)*100))
#print("Accuracy of the RNN model for this data: " + str(accuracy_score(RNNprediction, y_test)*100))
print("Accuracy of the DTC model for this data: " + str(accuracy_score(DTCprediction, y_test)*100))
print("Accuracy of the RFC model for this data: " + str(accuracy_score(RFCprediction, y_test)*100))
print("Accuracy of the ETC model for this data: " + str(accuracy_score(ETCprediction, y_test)*100))
print("Accuracy of the GNB model for this data: " + str(accuracy_score(GNBprediction, y_test)*100))
print("Accuracy of the BNB model for this data: " + str(accuracy_score(BNBprediction, y_test)*100))
print("Accuracy of the LRG model for this data: " + str(accuracy_score(LRGprediction, y_test)*100))
print("Accuracy of the LDA model for this data: " + str(accuracy_score(LDAprediction, y_test)*100))
print("Accuracy of the MLP model for this data: " + str(accuracy_score(MLPprediction, y_test)*100))


#print("Precision of the SVM model for this data: " + str(np.mean(precision_score(SVMprediction, y_test, average=None))))
print("Precision of the KNN model for this data: " + str(np.mean(precision_score(KNNprediction, y_test, average=None))))
#print("Precision of the RNN model for this data: " + str(np.mean(precision_score(RNNprediction, y_test, average=None))))
print("Precision of the DTC model for this data: " + str(np.mean(precision_score(DTCprediction, y_test, average=None))))
print("Precision of the RFC model for this data: " + str(np.mean(precision_score(RFCprediction, y_test, average=None))))
print("Precision of the ETC model for this data: " + str(np.mean(precision_score(ETCprediction, y_test, average=None))))
print("Precision of the GNB model for this data: " + str(np.mean(precision_score(GNBprediction, y_test, average=None))))
print("Precision of the BNB model for this data: " + str(np.mean(precision_score(BNBprediction, y_test, average=None))))
print("Precision of the LRG model for this data: " + str(np.mean(precision_score(LRGprediction, y_test, average=None))))
print("Precision of the LDA model for this data: " + str(np.mean(precision_score(LDAprediction, y_test, average=None))))
print("Precision of the MLP model for this data: " + str(np.mean(precision_score(MLPprediction, y_test, average=None))))



#print("Recall of the SVM model for this data: " + str(np.mean(recall_score(SVMprediction, y_test, average=None))))
print("Recall of the KNN model for this data: " + str(np.mean(recall_score(KNNprediction, y_test, average=None))))
#print("Recall of the RNN model for this data: " + str(np.mean(recall_score(RNNprediction, y_test, average=None))))
print("Recall of the DTC model for this data: " + str(np.mean(recall_score(DTCprediction, y_test, average=None))))
print("Recall of the RFC model for this data: " + str(np.mean(recall_score(RFCprediction, y_test, average=None))))
print("Recall of the ETC model for this data: " + str(np.mean(recall_score(ETCprediction, y_test, average=None))))
print("Recall of the GNB model for this data: " + str(np.mean(recall_score(GNBprediction, y_test, average=None))))
print("Recall of the BNB model for this data: " + str(np.mean(recall_score(BNBprediction, y_test, average=None))))
print("Recall of the LRG model for this data: " + str(np.mean(recall_score(LRGprediction, y_test, average=None))))
print("Recall of the LDA model for this data: " + str(np.mean(recall_score(LDAprediction, y_test, average=None))))
print("Recall of the MLP model for this data: " + str(np.mean(recall_score(MLPprediction, y_test, average=None))))


#print("F1_score of the SVM model for this data: " + str(np.mean(f1_score(SVMprediction, y_test, average=None))))
print("F1_score of the KNN model for this data: " + str(np.mean(f1_score(KNNprediction, y_test, average=None))))
#print("F1_score of the RNN model for this data: " + str(np.mean(f1_score(RNNprediction, y_test, average=None))))
print("F1_score of the DTC model for this data: " + str(np.mean(f1_score(DTCprediction, y_test, average=None))))
print("F1_score of the RFC model for this data: " + str(np.mean(f1_score(RFCprediction, y_test, average=None))))
print("F1_score of the ETC model for this data: " + str(np.mean(f1_score(ETCprediction, y_test, average=None))))
print("F1_score of the GNB model for this data: " + str(np.mean(f1_score(GNBprediction, y_test, average=None))))
print("F1_score of the BNB model for this data: " + str(np.mean(f1_score(BNBprediction, y_test, average=None))))
print("F1_score of the LRG model for this data: " + str(np.mean(f1_score(LRGprediction, y_test, average=None))))
print("F1_score of the LDA model for this data: " + str(np.mean(f1_score(LDAprediction, y_test, average=None))))
print("F1_score of the MLP model for this data: " + str(np.mean(f1_score(MLPprediction, y_test, average=None))))


#print("Jaccard_score of the SVM model for this data: " + str(np.mean(jaccard_score(SVMprediction, y_test, average=None))))
print("Jaccard_score of the KNN model for this data: " + str(np.mean(jaccard_score(KNNprediction, y_test, average=None))))
#print("Jaccard_score of the RNN model for this data: " + str(np.mean(jaccard_score(RNNprediction, y_test, average=None))))
print("Jaccard_score of the DTC model for this data: " + str(np.mean(jaccard_score(DTCprediction, y_test, average=None))))
print("Jaccard_score of the RFC model for this data: " + str(np.mean(jaccard_score(RFCprediction, y_test, average=None))))
print("Jaccard_score of the ETC model for this data: " + str(np.mean(jaccard_score(ETCprediction, y_test, average=None))))
print("Jaccard_score of the GNB model for this data: " + str(np.mean(jaccard_score(GNBprediction, y_test, average=None))))
print("Jaccard_score of the BNB model for this data: " + str(np.mean(jaccard_score(BNBprediction, y_test, average=None))))
print("Jaccard_score of the LRG model for this data: " + str(np.mean(jaccard_score(LRGprediction, y_test, average=None))))
print("Jaccard_score of the LDA model for this data: " + str(np.mean(jaccard_score(LDAprediction, y_test, average=None))))
print("Jaccard_score of the MLP model for this data: " + str(np.mean(jaccard_score(MLPprediction, y_test, average=None))))


#print("Kohen_Kappa_score of the SVM model for this data: " + str(np.mean(cohen_kappa_score(SVMprediction, y_test))))
print("Kohen_Kappa_score of the KNN model for this data: " + str(np.mean(cohen_kappa_score(KNNprediction, y_test))))
#print("Kohen_Kappa_score of the RNN model for this data: " + str(np.mean(cohen_kappa_score(RNNprediction, y_test))))
print("Kohen_Kappa_score of the DTC model for this data: " + str(np.mean(cohen_kappa_score(DTCprediction, y_test))))
print("Kohen_Kappa_score of the RFC model for this data: " + str(np.mean(cohen_kappa_score(RFCprediction, y_test))))
print("Kohen_Kappa_score of the ETC model for this data: " + str(np.mean(cohen_kappa_score(ETCprediction, y_test))))
print("Kohen_Kappa_score of the GNB model for this data: " + str(np.mean(cohen_kappa_score(GNBprediction, y_test))))
print("Kohen_Kappa_score of the BNB model for this data: " + str(np.mean(cohen_kappa_score(BNBprediction, y_test))))
print("Kohen_Kappa_score of the LRG model for this data: " + str(np.mean(cohen_kappa_score(LRGprediction, y_test))))
print("Kohen_Kappa_score of the LDA model for this data: " + str(np.mean(cohen_kappa_score(LDAprediction, y_test))))
print("Kohen_Kappa_score of the MLP model for this data: " + str(np.mean(cohen_kappa_score(MLPprediction, y_test))))


#print("Hamming_Loss of the SVM model for this data: " + str(np.mean(hamming_loss(SVMprediction, y_test))))
print("Hamming_Loss of the KNN model for this data: " + str(np.mean(hamming_loss(KNNprediction, y_test))))
#print("Hamming_Loss of the RNN model for this data: " + str(np.mean(hamming_loss(RNNprediction, y_test))))
print("Hamming_Loss of the DTC model for this data: " + str(np.mean(hamming_loss(DTCprediction, y_test))))
print("Hamming_Loss of the RFC model for this data: " + str(np.mean(hamming_loss(RFCprediction, y_test))))
print("Hamming_Loss of the ETC model for this data: " + str(np.mean(hamming_loss(ETCprediction, y_test))))
print("Hamming_Loss of the GNB model for this data: " + str(np.mean(hamming_loss(GNBprediction, y_test))))
print("Hamming_Loss of the BNB model for this data: " + str(np.mean(hamming_loss(BNBprediction, y_test))))
print("Hamming_Loss of the LRG model for this data: " + str(np.mean(hamming_loss(LRGprediction, y_test))))
print("Hamming_Loss of the LDA model for this data: " + str(np.mean(hamming_loss(LDAprediction, y_test))))
print("Hamming_Loss of the MLP model for this data: " + str(np.mean(hamming_loss(MLPprediction, y_test))))


#print("Matthews_corrcoef of the SVM model for this data: " + str(np.mean(matthews_corrcoef(SVMprediction, y_test))))
print("Matthews_corrcoef of the KNN model for this data: " + str(np.mean(matthews_corrcoef(KNNprediction, y_test))))
#print("Matthews_corrcoef of the RNN model for this data: " + str(np.mean(matthews_corrcoef(RNNprediction, y_test))))
print("Matthews_corrcoef of the DTC model for this data: " + str(np.mean(matthews_corrcoef(DTCprediction, y_test))))
print("Matthews_corrcoef of the RFC model for this data: " + str(np.mean(matthews_corrcoef(RFCprediction, y_test))))
print("Matthews_corrcoef of the ETC model for this data: " + str(np.mean(matthews_corrcoef(ETCprediction, y_test))))
print("Matthews_corrcoef of the GNB model for this data: " + str(np.mean(matthews_corrcoef(GNBprediction, y_test))))
print("Matthews_corrcoef of the BNB model for this data: " + str(np.mean(matthews_corrcoef(BNBprediction, y_test))))
print("Matthews_corrcoef of the LRG model for this data: " + str(np.mean(matthews_corrcoef(LRGprediction, y_test))))
print("Matthews_corrcoef of the LDA model for this data: " + str(np.mean(matthews_corrcoef(LDAprediction, y_test))))
print("Matthews_corrcoef of the MLP model for this data: " + str(np.mean(matthews_corrcoef(MLPprediction, y_test))))
# Out:
# /home/subhrangshu/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /tmp/ipykernel_7932/627727132.py:39: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFCmodel = RFCmodel.fit(X_train, y_train)
# Train time for KNN: 17.800092697143555
# Train time for DTC: 59.20672416687012
# Train time for RFC: 1250.9827613830566
# Train time for ETC: 10.829687118530273
# Train time for GNB: 9.750604629516602
# Train time for BNB: 19.939899444580078
# ...

# %%
# Out:
#                  0         1         2
# 0         0.040371  0.158656  0.010788
# 1         0.532315 -0.132099  0.510404
# 2        -0.354097 -0.259882 -0.137752
# 3        -0.044126 -0.247673 -0.063657
# 4        -0.845585  0.157730  0.061823
# ...            ...       ...       ...
# 19232054 -0.008963 -0.048836  0.112169
# 19232055  0.207172 -0.347377  0.362442
# 19232056 -0.269379  0.173986  0.069903
# 19232057  0.049537  0.001917  0.015127
# 19232058 -0.331697  0.110974  0.029552
#
# [19232059 rows x 3 columns]

# %%
fulldata = fulldata.sample(frac=1).reset_index(drop=True)
X = fulldata[['Ar','Al','Pl','Pr','Lr']]
y = fulldata[['Category']]
pca = decomposition.PCA(n_components=3)
a = time.time()
X = pca.fit_transform(X)
b = time.time()
print('Decomposition time ' + str((b-a)*1000))
X = pd.DataFrame(X)
data = pd.concat([X,y],axis=1)

fulldatatrain = data[:200000]
fulldatatest = data[200000:264600]
X_train = fulldatatrain[[0,1,2]]
y_train = fulldatatrain[['Category']]
X_test = fulldatatest[[0,1,2]]
y_test = fulldatatest[['Category']]

#SVMmodel = SVC(gamma='auto')
#a = time.time()
#SVMmodel = SVMmodel.fit(X_train, y_train)
#b = time.time()
#print('Train time for SVM: ' + str((b-a)*1000))


KNNmodel = KNeighborsClassifier(n_neighbors=1)
a = time.time()
KNNmodel = KNNmodel.fit(X_train, y_train)
b = time.time()
print('Train time for KNN: ' + str((b-a)*1000))


#RNNmodel = RadiusNeighborsClassifier(radius=1.085)
#a = time.time()
#RNNmodel = RNNmodel.fit(X_train, y_train)
#b = time.time()
#print('Train time for RNN: ' + str((b-a)*1000))


DTCmodel = DecisionTreeClassifier()
a = time.time()
DTCmodel = DTCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for DTC: ' + str((b-a)*1000))


RFCmodel = RandomForestClassifier(n_estimators=100)
a = time.time()
RFCmodel = RFCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for RFC: ' + str((b-a)*1000))


ETCmodel = ExtraTreeClassifier()
a = time.time()
ETCmodel = ETCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for ETC: ' + str((b-a)*1000))


GNBmodel = GaussianNB()
a = time.time()
GNBmodel = GNBmodel.fit(X_train,y_train)
b = time.time()
print('Train time for GNB: ' + str((b-a)*1000))


BNBmodel = BernoulliNB()
a = time.time()
BNBmodel = BNBmodel.fit(X_train,y_train)
b = time.time()
print('Train time for BNB: ' + str((b-a)*1000))


LRGmodel = LogisticRegression(solver='lbfgs')
a = time.time()
LRGmodel = LRGmodel.fit(X_train, y_train)
b = time.time()
print('Train time for LRG: ' + str((b-a)*1000))


LDAmodel = LinearDiscriminantAnalysis()
a = time.time()
LDAmodel = LDAmodel.fit(X_train, y_train)
b = time.time()
print('Train time for LDA: ' + str((b-a)*1000))


MLPmodel = MLPClassifier(solver='lbfgs')
a = time.time()
MLPmodel = MLPmodel.fit(X_train, y_train)
b = time.time()
print('Train time for MLP: ' + str((b-a)*1000))


#a = time.time()
#SVMprediction = SVMmodel.predict(X_test)
#b = time.time()
#print('Prediction time for SVM: ' + str((b-a)*1000))

a = time.time()
KNNprediction = KNNmodel.predict(X_test)
b = time.time()
print('Prediction time for KNN: ' + str((b-a)*1000))

#a = time.time()
#RNNprediction = RNNmodel.predict(X_test)
#b = time.time()
#print('Prediction time for SVM: ' + str((b-a)*1000))

a = time.time()
DTCprediction = DTCmodel.predict(X_test)
b = time.time()
print('Prediction time for DTC: ' + str((b-a)*1000))

a = time.time()
RFCprediction = RFCmodel.predict(X_test)
b = time.time()
print('Prediction time for RFC: ' + str((b-a)*1000))

a = time.time()
ETCprediction = ETCmodel.predict(X_test)
b = time.time()
print('Prediction time for ETC: ' + str((b-a)*1000))

a = time.time()
GNBprediction = GNBmodel.predict(X_test)
b = time.time()
print('Prediction time for GNB: ' + str((b-a)*1000))

a = time.time()
BNBprediction = BNBmodel.predict(X_test)
b = time.time()
print('Prediction time for BNB: ' + str((b-a)*1000))

a = time.time()
LRGprediction = LRGmodel.predict(X_test)
b = time.time()
print('Prediction time for LRG: ' + str((b-a)*1000))

a = time.time()
LDAprediction = LDAmodel.predict(X_test)
b = time.time()
print('Prediction time for LDA: ' + str((b-a)*1000))

a = time.time()
MLPprediction = MLPmodel.predict(X_test)
b = time.time()
print('Prediction time for MLP: ' + str((b-a)*1000))

#print("Accuracy of the SVM model for this data: " + str(accuracy_score(SVMprediction, y_test)*100))
print("Accuracy of the KNN model for this data: " + str(accuracy_score(KNNprediction, y_test)*100))
#print("Accuracy of the RNN model for this data: " + str(accuracy_score(RNNprediction, y_test)*100))
print("Accuracy of the DTC model for this data: " + str(accuracy_score(DTCprediction, y_test)*100))
print("Accuracy of the RFC model for this data: " + str(accuracy_score(RFCprediction, y_test)*100))
print("Accuracy of the ETC model for this data: " + str(accuracy_score(ETCprediction, y_test)*100))
print("Accuracy of the GNB model for this data: " + str(accuracy_score(GNBprediction, y_test)*100))
print("Accuracy of the BNB model for this data: " + str(accuracy_score(BNBprediction, y_test)*100))
print("Accuracy of the LRG model for this data: " + str(accuracy_score(LRGprediction, y_test)*100))
print("Accuracy of the LDA model for this data: " + str(accuracy_score(LDAprediction, y_test)*100))
print("Accuracy of the MLP model for this data: " + str(accuracy_score(MLPprediction, y_test)*100))


#print("Precision of the SVM model for this data: " + str(np.mean(precision_score(SVMprediction, y_test, average=None))))
print("Precision of the KNN model for this data: " + str(np.mean(precision_score(KNNprediction, y_test, average=None))))
#print("Precision of the RNN model for this data: " + str(np.mean(precision_score(RNNprediction, y_test, average=None))))
print("Precision of the DTC model for this data: " + str(np.mean(precision_score(DTCprediction, y_test, average=None))))
print("Precision of the RFC model for this data: " + str(np.mean(precision_score(RFCprediction, y_test, average=None))))
print("Precision of the ETC model for this data: " + str(np.mean(precision_score(ETCprediction, y_test, average=None))))
print("Precision of the GNB model for this data: " + str(np.mean(precision_score(GNBprediction, y_test, average=None))))
print("Precision of the BNB model for this data: " + str(np.mean(precision_score(BNBprediction, y_test, average=None))))
print("Precision of the LRG model for this data: " + str(np.mean(precision_score(LRGprediction, y_test, average=None))))
print("Precision of the LDA model for this data: " + str(np.mean(precision_score(LDAprediction, y_test, average=None))))
print("Precision of the MLP model for this data: " + str(np.mean(precision_score(MLPprediction, y_test, average=None))))



#print("Recall of the SVM model for this data: " + str(np.mean(recall_score(SVMprediction, y_test, average=None))))
print("Recall of the KNN model for this data: " + str(np.mean(recall_score(KNNprediction, y_test, average=None))))
#print("Recall of the RNN model for this data: " + str(np.mean(recall_score(RNNprediction, y_test, average=None))))
print("Recall of the DTC model for this data: " + str(np.mean(recall_score(DTCprediction, y_test, average=None))))
print("Recall of the RFC model for this data: " + str(np.mean(recall_score(RFCprediction, y_test, average=None))))
print("Recall of the ETC model for this data: " + str(np.mean(recall_score(ETCprediction, y_test, average=None))))
print("Recall of the GNB model for this data: " + str(np.mean(recall_score(GNBprediction, y_test, average=None))))
print("Recall of the BNB model for this data: " + str(np.mean(recall_score(BNBprediction, y_test, average=None))))
print("Recall of the LRG model for this data: " + str(np.mean(recall_score(LRGprediction, y_test, average=None))))
print("Recall of the LDA model for this data: " + str(np.mean(recall_score(LDAprediction, y_test, average=None))))
print("Recall of the MLP model for this data: " + str(np.mean(recall_score(MLPprediction, y_test, average=None))))


#print("F1_score of the SVM model for this data: " + str(np.mean(f1_score(SVMprediction, y_test, average=None))))
print("F1_score of the KNN model for this data: " + str(np.mean(f1_score(KNNprediction, y_test, average=None))))
#print("F1_score of the RNN model for this data: " + str(np.mean(f1_score(RNNprediction, y_test, average=None))))
print("F1_score of the DTC model for this data: " + str(np.mean(f1_score(DTCprediction, y_test, average=None))))
print("F1_score of the RFC model for this data: " + str(np.mean(f1_score(RFCprediction, y_test, average=None))))
print("F1_score of the ETC model for this data: " + str(np.mean(f1_score(ETCprediction, y_test, average=None))))
print("F1_score of the GNB model for this data: " + str(np.mean(f1_score(GNBprediction, y_test, average=None))))
print("F1_score of the BNB model for this data: " + str(np.mean(f1_score(BNBprediction, y_test, average=None))))
print("F1_score of the LRG model for this data: " + str(np.mean(f1_score(LRGprediction, y_test, average=None))))
print("F1_score of the LDA model for this data: " + str(np.mean(f1_score(LDAprediction, y_test, average=None))))
print("F1_score of the MLP model for this data: " + str(np.mean(f1_score(MLPprediction, y_test, average=None))))


#print("Jaccard_score of the SVM model for this data: " + str(np.mean(jaccard_score(SVMprediction, y_test, average=None))))
print("Jaccard_score of the KNN model for this data: " + str(np.mean(jaccard_score(KNNprediction, y_test, average=None))))
#print("Jaccard_score of the RNN model for this data: " + str(np.mean(jaccard_score(RNNprediction, y_test, average=None))))
print("Jaccard_score of the DTC model for this data: " + str(np.mean(jaccard_score(DTCprediction, y_test, average=None))))
print("Jaccard_score of the RFC model for this data: " + str(np.mean(jaccard_score(RFCprediction, y_test, average=None))))
print("Jaccard_score of the ETC model for this data: " + str(np.mean(jaccard_score(ETCprediction, y_test, average=None))))
print("Jaccard_score of the GNB model for this data: " + str(np.mean(jaccard_score(GNBprediction, y_test, average=None))))
print("Jaccard_score of the BNB model for this data: " + str(np.mean(jaccard_score(BNBprediction, y_test, average=None))))
print("Jaccard_score of the LRG model for this data: " + str(np.mean(jaccard_score(LRGprediction, y_test, average=None))))
print("Jaccard_score of the LDA model for this data: " + str(np.mean(jaccard_score(LDAprediction, y_test, average=None))))
print("Jaccard_score of the MLP model for this data: " + str(np.mean(jaccard_score(MLPprediction, y_test, average=None))))


#print("Kohen_Kappa_score of the SVM model for this data: " + str(np.mean(cohen_kappa_score(SVMprediction, y_test))))
print("Kohen_Kappa_score of the KNN model for this data: " + str(np.mean(cohen_kappa_score(KNNprediction, y_test))))
#print("Kohen_Kappa_score of the RNN model for this data: " + str(np.mean(cohen_kappa_score(RNNprediction, y_test))))
print("Kohen_Kappa_score of the DTC model for this data: " + str(np.mean(cohen_kappa_score(DTCprediction, y_test))))
print("Kohen_Kappa_score of the RFC model for this data: " + str(np.mean(cohen_kappa_score(RFCprediction, y_test))))
print("Kohen_Kappa_score of the ETC model for this data: " + str(np.mean(cohen_kappa_score(ETCprediction, y_test))))
print("Kohen_Kappa_score of the GNB model for this data: " + str(np.mean(cohen_kappa_score(GNBprediction, y_test))))
print("Kohen_Kappa_score of the BNB model for this data: " + str(np.mean(cohen_kappa_score(BNBprediction, y_test))))
print("Kohen_Kappa_score of the LRG model for this data: " + str(np.mean(cohen_kappa_score(LRGprediction, y_test))))
print("Kohen_Kappa_score of the LDA model for this data: " + str(np.mean(cohen_kappa_score(LDAprediction, y_test))))
print("Kohen_Kappa_score of the MLP model for this data: " + str(np.mean(cohen_kappa_score(MLPprediction, y_test))))


#print("Hamming_Loss of the SVM model for this data: " + str(np.mean(hamming_loss(SVMprediction, y_test))))
print("Hamming_Loss of the KNN model for this data: " + str(np.mean(hamming_loss(KNNprediction, y_test))))
#print("Hamming_Loss of the RNN model for this data: " + str(np.mean(hamming_loss(RNNprediction, y_test))))
print("Hamming_Loss of the DTC model for this data: " + str(np.mean(hamming_loss(DTCprediction, y_test))))
print("Hamming_Loss of the RFC model for this data: " + str(np.mean(hamming_loss(RFCprediction, y_test))))
print("Hamming_Loss of the ETC model for this data: " + str(np.mean(hamming_loss(ETCprediction, y_test))))
print("Hamming_Loss of the GNB model for this data: " + str(np.mean(hamming_loss(GNBprediction, y_test))))
print("Hamming_Loss of the BNB model for this data: " + str(np.mean(hamming_loss(BNBprediction, y_test))))
print("Hamming_Loss of the LRG model for this data: " + str(np.mean(hamming_loss(LRGprediction, y_test))))
print("Hamming_Loss of the LDA model for this data: " + str(np.mean(hamming_loss(LDAprediction, y_test))))
print("Hamming_Loss of the MLP model for this data: " + str(np.mean(hamming_loss(MLPprediction, y_test))))


#print("Matthews_corrcoef of the SVM model for this data: " + str(np.mean(matthews_corrcoef(SVMprediction, y_test))))
print("Matthews_corrcoef of the KNN model for this data: " + str(np.mean(matthews_corrcoef(KNNprediction, y_test))))
#print("Matthews_corrcoef of the RNN model for this data: " + str(np.mean(matthews_corrcoef(RNNprediction, y_test))))
print("Matthews_corrcoef of the DTC model for this data: " + str(np.mean(matthews_corrcoef(DTCprediction, y_test))))
print("Matthews_corrcoef of the RFC model for this data: " + str(np.mean(matthews_corrcoef(RFCprediction, y_test))))
print("Matthews_corrcoef of the ETC model for this data: " + str(np.mean(matthews_corrcoef(ETCprediction, y_test))))
print("Matthews_corrcoef of the GNB model for this data: " + str(np.mean(matthews_corrcoef(GNBprediction, y_test))))
print("Matthews_corrcoef of the BNB model for this data: " + str(np.mean(matthews_corrcoef(BNBprediction, y_test))))
print("Matthews_corrcoef of the LRG model for this data: " + str(np.mean(matthews_corrcoef(LRGprediction, y_test))))
print("Matthews_corrcoef of the LDA model for this data: " + str(np.mean(matthews_corrcoef(LDAprediction, y_test))))
print("Matthews_corrcoef of the MLP model for this data: " + str(np.mean(matthews_corrcoef(MLPprediction, y_test))))
# Out:
# Decomposition time 16099.96485710144
# /home/subhrangshu/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Train time for KNN: 355.55458068847656
# Train time for DTC: 1831.7325115203857
# /tmp/ipykernel_32279/4025967127.py:49: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFCmodel = RFCmodel.fit(X_train, y_train)
# Train time for RFC: 37082.13233947754
# Train time for ETC: 295.4897880554199
# /home/subhrangshu/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
fulldata = fulldata.sample(frac=1).reset_index(drop=True)
X = fulldata[['Ar','Al','Pl','Pr','Lr']]
y = fulldata[['Category']]
pca = decomposition.PCA(n_components=2)
a = time.time()
X = pca.fit_transform(X)
b = time.time()
print('Decomposition time ' + str((b-a)*1000))
X = pd.DataFrame(X)
data = pd.concat([X,y],axis=1)

fulldatatrain = data[:200000]
fulldatatest = data[200000:264600]
X_train = fulldatatrain[[0,1]]
y_train = fulldatatrain[['Category']]
X_test = fulldatatest[[0,1]]
y_test = fulldatatest[['Category']]

#SVMmodel = SVC(gamma='auto')
#a = time.time()
#SVMmodel = SVMmodel.fit(X_train, y_train)
#b = time.time()
#print('Train time for SVM: ' + str((b-a)*1000))


KNNmodel = KNeighborsClassifier(n_neighbors=1)
a = time.time()
KNNmodel = KNNmodel.fit(X_train, y_train)
b = time.time()
print('Train time for KNN: ' + str((b-a)*1000))


#RNNmodel = RadiusNeighborsClassifier(radius=1.085)
#a = time.time()
#RNNmodel = RNNmodel.fit(X_train, y_train)
#b = time.time()
#print('Train time for RNN: ' + str((b-a)*1000))


DTCmodel = DecisionTreeClassifier()
a = time.time()
DTCmodel = DTCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for DTC: ' + str((b-a)*1000))


RFCmodel = RandomForestClassifier(n_estimators=100)
a = time.time()
RFCmodel = RFCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for RFC: ' + str((b-a)*1000))


ETCmodel = ExtraTreeClassifier()
a = time.time()
ETCmodel = ETCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for ETC: ' + str((b-a)*1000))


GNBmodel = GaussianNB()
a = time.time()
GNBmodel = GNBmodel.fit(X_train,y_train)
b = time.time()
print('Train time for GNB: ' + str((b-a)*1000))


BNBmodel = BernoulliNB()
a = time.time()
BNBmodel = BNBmodel.fit(X_train,y_train)
b = time.time()
print('Train time for BNB: ' + str((b-a)*1000))


LRGmodel = LogisticRegression(solver='lbfgs')
a = time.time()
LRGmodel = LRGmodel.fit(X_train, y_train)
b = time.time()
print('Train time for LRG: ' + str((b-a)*1000))


LDAmodel = LinearDiscriminantAnalysis()
a = time.time()
LDAmodel = LDAmodel.fit(X_train, y_train)
b = time.time()
print('Train time for LDA: ' + str((b-a)*1000))


MLPmodel = MLPClassifier(solver='lbfgs')
a = time.time()
MLPmodel = MLPmodel.fit(X_train, y_train)
b = time.time()
print('Train time for MLP: ' + str((b-a)*1000))


#a = time.time()
#SVMprediction = SVMmodel.predict(X_test)
#b = time.time()
#print('Prediction time for SVM: ' + str((b-a)*1000))

a = time.time()
KNNprediction = KNNmodel.predict(X_test)
b = time.time()
print('Prediction time for KNN: ' + str((b-a)*1000))

#a = time.time()
#RNNprediction = RNNmodel.predict(X_test)
#b = time.time()
#print('Prediction time for SVM: ' + str((b-a)*1000))

a = time.time()
DTCprediction = DTCmodel.predict(X_test)
b = time.time()
print('Prediction time for DTC: ' + str((b-a)*1000))

a = time.time()
RFCprediction = RFCmodel.predict(X_test)
b = time.time()
print('Prediction time for RFC: ' + str((b-a)*1000))

a = time.time()
ETCprediction = ETCmodel.predict(X_test)
b = time.time()
print('Prediction time for ETC: ' + str((b-a)*1000))

a = time.time()
GNBprediction = GNBmodel.predict(X_test)
b = time.time()
print('Prediction time for GNB: ' + str((b-a)*1000))

a = time.time()
BNBprediction = BNBmodel.predict(X_test)
b = time.time()
print('Prediction time for BNB: ' + str((b-a)*1000))

a = time.time()
LRGprediction = LRGmodel.predict(X_test)
b = time.time()
print('Prediction time for LRG: ' + str((b-a)*1000))

a = time.time()
LDAprediction = LDAmodel.predict(X_test)
b = time.time()
print('Prediction time for LDA: ' + str((b-a)*1000))

a = time.time()
MLPprediction = MLPmodel.predict(X_test)
b = time.time()
print('Prediction time for MLP: ' + str((b-a)*1000))

#print("Accuracy of the SVM model for this data: " + str(accuracy_score(SVMprediction, y_test)*100))
print("Accuracy of the KNN model for this data: " + str(accuracy_score(KNNprediction, y_test)*100))
#print("Accuracy of the RNN model for this data: " + str(accuracy_score(RNNprediction, y_test)*100))
print("Accuracy of the DTC model for this data: " + str(accuracy_score(DTCprediction, y_test)*100))
print("Accuracy of the RFC model for this data: " + str(accuracy_score(RFCprediction, y_test)*100))
print("Accuracy of the ETC model for this data: " + str(accuracy_score(ETCprediction, y_test)*100))
print("Accuracy of the GNB model for this data: " + str(accuracy_score(GNBprediction, y_test)*100))
print("Accuracy of the BNB model for this data: " + str(accuracy_score(BNBprediction, y_test)*100))
print("Accuracy of the LRG model for this data: " + str(accuracy_score(LRGprediction, y_test)*100))
print("Accuracy of the LDA model for this data: " + str(accuracy_score(LDAprediction, y_test)*100))
print("Accuracy of the MLP model for this data: " + str(accuracy_score(MLPprediction, y_test)*100))


#print("Precision of the SVM model for this data: " + str(np.mean(precision_score(SVMprediction, y_test, average=None))))
print("Precision of the KNN model for this data: " + str(np.mean(precision_score(KNNprediction, y_test, average=None))))
#print("Precision of the RNN model for this data: " + str(np.mean(precision_score(RNNprediction, y_test, average=None))))
print("Precision of the DTC model for this data: " + str(np.mean(precision_score(DTCprediction, y_test, average=None))))
print("Precision of the RFC model for this data: " + str(np.mean(precision_score(RFCprediction, y_test, average=None))))
print("Precision of the ETC model for this data: " + str(np.mean(precision_score(ETCprediction, y_test, average=None))))
print("Precision of the GNB model for this data: " + str(np.mean(precision_score(GNBprediction, y_test, average=None))))
print("Precision of the BNB model for this data: " + str(np.mean(precision_score(BNBprediction, y_test, average=None))))
print("Precision of the LRG model for this data: " + str(np.mean(precision_score(LRGprediction, y_test, average=None))))
print("Precision of the LDA model for this data: " + str(np.mean(precision_score(LDAprediction, y_test, average=None))))
print("Precision of the MLP model for this data: " + str(np.mean(precision_score(MLPprediction, y_test, average=None))))



#print("Recall of the SVM model for this data: " + str(np.mean(recall_score(SVMprediction, y_test, average=None))))
print("Recall of the KNN model for this data: " + str(np.mean(recall_score(KNNprediction, y_test, average=None))))
#print("Recall of the RNN model for this data: " + str(np.mean(recall_score(RNNprediction, y_test, average=None))))
print("Recall of the DTC model for this data: " + str(np.mean(recall_score(DTCprediction, y_test, average=None))))
print("Recall of the RFC model for this data: " + str(np.mean(recall_score(RFCprediction, y_test, average=None))))
print("Recall of the ETC model for this data: " + str(np.mean(recall_score(ETCprediction, y_test, average=None))))
print("Recall of the GNB model for this data: " + str(np.mean(recall_score(GNBprediction, y_test, average=None))))
print("Recall of the BNB model for this data: " + str(np.mean(recall_score(BNBprediction, y_test, average=None))))
print("Recall of the LRG model for this data: " + str(np.mean(recall_score(LRGprediction, y_test, average=None))))
print("Recall of the LDA model for this data: " + str(np.mean(recall_score(LDAprediction, y_test, average=None))))
print("Recall of the MLP model for this data: " + str(np.mean(recall_score(MLPprediction, y_test, average=None))))


#print("F1_score of the SVM model for this data: " + str(np.mean(f1_score(SVMprediction, y_test, average=None))))
print("F1_score of the KNN model for this data: " + str(np.mean(f1_score(KNNprediction, y_test, average=None))))
#print("F1_score of the RNN model for this data: " + str(np.mean(f1_score(RNNprediction, y_test, average=None))))
print("F1_score of the DTC model for this data: " + str(np.mean(f1_score(DTCprediction, y_test, average=None))))
print("F1_score of the RFC model for this data: " + str(np.mean(f1_score(RFCprediction, y_test, average=None))))
print("F1_score of the ETC model for this data: " + str(np.mean(f1_score(ETCprediction, y_test, average=None))))
print("F1_score of the GNB model for this data: " + str(np.mean(f1_score(GNBprediction, y_test, average=None))))
print("F1_score of the BNB model for this data: " + str(np.mean(f1_score(BNBprediction, y_test, average=None))))
print("F1_score of the LRG model for this data: " + str(np.mean(f1_score(LRGprediction, y_test, average=None))))
print("F1_score of the LDA model for this data: " + str(np.mean(f1_score(LDAprediction, y_test, average=None))))
print("F1_score of the MLP model for this data: " + str(np.mean(f1_score(MLPprediction, y_test, average=None))))


#print("Jaccard_score of the SVM model for this data: " + str(np.mean(jaccard_score(SVMprediction, y_test, average=None))))
print("Jaccard_score of the KNN model for this data: " + str(np.mean(jaccard_score(KNNprediction, y_test, average=None))))
#print("Jaccard_score of the RNN model for this data: " + str(np.mean(jaccard_score(RNNprediction, y_test, average=None))))
print("Jaccard_score of the DTC model for this data: " + str(np.mean(jaccard_score(DTCprediction, y_test, average=None))))
print("Jaccard_score of the RFC model for this data: " + str(np.mean(jaccard_score(RFCprediction, y_test, average=None))))
print("Jaccard_score of the ETC model for this data: " + str(np.mean(jaccard_score(ETCprediction, y_test, average=None))))
print("Jaccard_score of the GNB model for this data: " + str(np.mean(jaccard_score(GNBprediction, y_test, average=None))))
print("Jaccard_score of the BNB model for this data: " + str(np.mean(jaccard_score(BNBprediction, y_test, average=None))))
print("Jaccard_score of the LRG model for this data: " + str(np.mean(jaccard_score(LRGprediction, y_test, average=None))))
print("Jaccard_score of the LDA model for this data: " + str(np.mean(jaccard_score(LDAprediction, y_test, average=None))))
print("Jaccard_score of the MLP model for this data: " + str(np.mean(jaccard_score(MLPprediction, y_test, average=None))))


#print("Kohen_Kappa_score of the SVM model for this data: " + str(np.mean(cohen_kappa_score(SVMprediction, y_test))))
print("Kohen_Kappa_score of the KNN model for this data: " + str(np.mean(cohen_kappa_score(KNNprediction, y_test))))
#print("Kohen_Kappa_score of the RNN model for this data: " + str(np.mean(cohen_kappa_score(RNNprediction, y_test))))
print("Kohen_Kappa_score of the DTC model for this data: " + str(np.mean(cohen_kappa_score(DTCprediction, y_test))))
print("Kohen_Kappa_score of the RFC model for this data: " + str(np.mean(cohen_kappa_score(RFCprediction, y_test))))
print("Kohen_Kappa_score of the ETC model for this data: " + str(np.mean(cohen_kappa_score(ETCprediction, y_test))))
print("Kohen_Kappa_score of the GNB model for this data: " + str(np.mean(cohen_kappa_score(GNBprediction, y_test))))
print("Kohen_Kappa_score of the BNB model for this data: " + str(np.mean(cohen_kappa_score(BNBprediction, y_test))))
print("Kohen_Kappa_score of the LRG model for this data: " + str(np.mean(cohen_kappa_score(LRGprediction, y_test))))
print("Kohen_Kappa_score of the LDA model for this data: " + str(np.mean(cohen_kappa_score(LDAprediction, y_test))))
print("Kohen_Kappa_score of the MLP model for this data: " + str(np.mean(cohen_kappa_score(MLPprediction, y_test))))


#print("Hamming_Loss of the SVM model for this data: " + str(np.mean(hamming_loss(SVMprediction, y_test))))
print("Hamming_Loss of the KNN model for this data: " + str(np.mean(hamming_loss(KNNprediction, y_test))))
#print("Hamming_Loss of the RNN model for this data: " + str(np.mean(hamming_loss(RNNprediction, y_test))))
print("Hamming_Loss of the DTC model for this data: " + str(np.mean(hamming_loss(DTCprediction, y_test))))
print("Hamming_Loss of the RFC model for this data: " + str(np.mean(hamming_loss(RFCprediction, y_test))))
print("Hamming_Loss of the ETC model for this data: " + str(np.mean(hamming_loss(ETCprediction, y_test))))
print("Hamming_Loss of the GNB model for this data: " + str(np.mean(hamming_loss(GNBprediction, y_test))))
print("Hamming_Loss of the BNB model for this data: " + str(np.mean(hamming_loss(BNBprediction, y_test))))
print("Hamming_Loss of the LRG model for this data: " + str(np.mean(hamming_loss(LRGprediction, y_test))))
print("Hamming_Loss of the LDA model for this data: " + str(np.mean(hamming_loss(LDAprediction, y_test))))
print("Hamming_Loss of the MLP model for this data: " + str(np.mean(hamming_loss(MLPprediction, y_test))))


#print("Matthews_corrcoef of the SVM model for this data: " + str(np.mean(matthews_corrcoef(SVMprediction, y_test))))
print("Matthews_corrcoef of the KNN model for this data: " + str(np.mean(matthews_corrcoef(KNNprediction, y_test))))
#print("Matthews_corrcoef of the RNN model for this data: " + str(np.mean(matthews_corrcoef(RNNprediction, y_test))))
print("Matthews_corrcoef of the DTC model for this data: " + str(np.mean(matthews_corrcoef(DTCprediction, y_test))))
print("Matthews_corrcoef of the RFC model for this data: " + str(np.mean(matthews_corrcoef(RFCprediction, y_test))))
print("Matthews_corrcoef of the ETC model for this data: " + str(np.mean(matthews_corrcoef(ETCprediction, y_test))))
print("Matthews_corrcoef of the GNB model for this data: " + str(np.mean(matthews_corrcoef(GNBprediction, y_test))))
print("Matthews_corrcoef of the BNB model for this data: " + str(np.mean(matthews_corrcoef(BNBprediction, y_test))))
print("Matthews_corrcoef of the LRG model for this data: " + str(np.mean(matthews_corrcoef(LRGprediction, y_test))))
print("Matthews_corrcoef of the LDA model for this data: " + str(np.mean(matthews_corrcoef(LDAprediction, y_test))))
print("Matthews_corrcoef of the MLP model for this data: " + str(np.mean(matthews_corrcoef(MLPprediction, y_test))))
# Out:
# Decomposition time 17011.83819770813
# /home/subhrangshu/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Train time for KNN: 301.1045455932617
# Train time for DTC: 1454.0278911590576
# /tmp/ipykernel_32279/3912734392.py:49: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFCmodel = RFCmodel.fit(X_train, y_train)
# Train time for RFC: 42201.098918914795
# Train time for ETC: 306.3948154449463
# /home/subhrangshu/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
fulldata = fulldata.sample(frac=1).reset_index(drop=True)
X = fulldata[['Ar','Al','Pl','Pr','Lr']]
y = fulldata[['Category']]

lda = LinearDiscriminantAnalysis(n_components=2)
a = time.time()
X = lda.fit(X, y).transform(X)
b = time.time()
print('Decomposition time ' + str((b-a)*1000))
X = pd.DataFrame(X)
data = pd.concat([X,y],axis=1)

fulldatatrain = data[:200000]
fulldatatest = data[200000:264600]
X_train = fulldatatrain[[0,1]]
y_train = fulldatatrain[['Category']]
X_test = fulldatatest[[0,1]]
y_test = fulldatatest[['Category']]



#SVMmodel = SVC(gamma='auto')
#a = time.time()
#SVMmodel = SVMmodel.fit(X_train, y_train)
#b = time.time()
#print('Train time for SVM: ' + str((b-a)*1000))


KNNmodel = KNeighborsClassifier(n_neighbors=1)
a = time.time()
KNNmodel = KNNmodel.fit(X_train, y_train)
b = time.time()
print('Train time for KNN: ' + str((b-a)*1000))


#RNNmodel = RadiusNeighborsClassifier(radius=1.085)
#a = time.time()
#RNNmodel = RNNmodel.fit(X_train, y_train)
#b = time.time()
#print('Train time for RNN: ' + str((b-a)*1000))


DTCmodel = DecisionTreeClassifier()
a = time.time()
DTCmodel = DTCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for DTC: ' + str((b-a)*1000))


RFCmodel = RandomForestClassifier(n_estimators=100)
a = time.time()
RFCmodel = RFCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for RFC: ' + str((b-a)*1000))


ETCmodel = ExtraTreeClassifier()
a = time.time()
ETCmodel = ETCmodel.fit(X_train, y_train)
b = time.time()
print('Train time for ETC: ' + str((b-a)*1000))


GNBmodel = GaussianNB()
a = time.time()
GNBmodel = GNBmodel.fit(X_train,y_train)
b = time.time()
print('Train time for GNB: ' + str((b-a)*1000))


BNBmodel = BernoulliNB()
a = time.time()
BNBmodel = BNBmodel.fit(X_train,y_train)
b = time.time()
print('Train time for BNB: ' + str((b-a)*1000))


LRGmodel = LogisticRegression(solver='lbfgs')
a = time.time()
LRGmodel = LRGmodel.fit(X_train, y_train)
b = time.time()
print('Train time for LRG: ' + str((b-a)*1000))


LDAmodel = LinearDiscriminantAnalysis()
a = time.time()
LDAmodel = LDAmodel.fit(X_train, y_train)
b = time.time()
print('Train time for LDA: ' + str((b-a)*1000))


MLPmodel = MLPClassifier(solver='lbfgs')
a = time.time()
MLPmodel = MLPmodel.fit(X_train, y_train)
b = time.time()
print('Train time for MLP: ' + str((b-a)*1000))


#a = time.time()
#SVMprediction = SVMmodel.predict(X_test)
#b = time.time()
#print('Prediction time for SVM: ' + str((b-a)*1000))

a = time.time()
KNNprediction = KNNmodel.predict(X_test)
b = time.time()
print('Prediction time for KNN: ' + str((b-a)*1000))

#a = time.time()
#RNNprediction = RNNmodel.predict(X_test)
#b = time.time()
#print('Prediction time for SVM: ' + str((b-a)*1000))

a = time.time()
DTCprediction = DTCmodel.predict(X_test)
b = time.time()
print('Prediction time for DTC: ' + str((b-a)*1000))

a = time.time()
RFCprediction = RFCmodel.predict(X_test)
b = time.time()
print('Prediction time for RFC: ' + str((b-a)*1000))

a = time.time()
ETCprediction = ETCmodel.predict(X_test)
b = time.time()
print('Prediction time for ETC: ' + str((b-a)*1000))

a = time.time()
GNBprediction = GNBmodel.predict(X_test)
b = time.time()
print('Prediction time for GNB: ' + str((b-a)*1000))

a = time.time()
BNBprediction = BNBmodel.predict(X_test)
b = time.time()
print('Prediction time for BNB: ' + str((b-a)*1000))

a = time.time()
LRGprediction = LRGmodel.predict(X_test)
b = time.time()
print('Prediction time for LRG: ' + str((b-a)*1000))

a = time.time()
LDAprediction = LDAmodel.predict(X_test)
b = time.time()
print('Prediction time for LDA: ' + str((b-a)*1000))

a = time.time()
MLPprediction = MLPmodel.predict(X_test)
b = time.time()
print('Prediction time for MLP: ' + str((b-a)*1000))

#print("Accuracy of the SVM model for this data: " + str(accuracy_score(SVMprediction, y_test)*100))
print("Accuracy of the KNN model for this data: " + str(accuracy_score(KNNprediction, y_test)*100))
#print("Accuracy of the RNN model for this data: " + str(accuracy_score(RNNprediction, y_test)*100))
print("Accuracy of the DTC model for this data: " + str(accuracy_score(DTCprediction, y_test)*100))
print("Accuracy of the RFC model for this data: " + str(accuracy_score(RFCprediction, y_test)*100))
print("Accuracy of the ETC model for this data: " + str(accuracy_score(ETCprediction, y_test)*100))
print("Accuracy of the GNB model for this data: " + str(accuracy_score(GNBprediction, y_test)*100))
print("Accuracy of the BNB model for this data: " + str(accuracy_score(BNBprediction, y_test)*100))
print("Accuracy of the LRG model for this data: " + str(accuracy_score(LRGprediction, y_test)*100))
print("Accuracy of the LDA model for this data: " + str(accuracy_score(LDAprediction, y_test)*100))
print("Accuracy of the MLP model for this data: " + str(accuracy_score(MLPprediction, y_test)*100))


#print("Precision of the SVM model for this data: " + str(np.mean(precision_score(SVMprediction, y_test, average=None))))
print("Precision of the KNN model for this data: " + str(np.mean(precision_score(KNNprediction, y_test, average=None))))
#print("Precision of the RNN model for this data: " + str(np.mean(precision_score(RNNprediction, y_test, average=None))))
print("Precision of the DTC model for this data: " + str(np.mean(precision_score(DTCprediction, y_test, average=None))))
print("Precision of the RFC model for this data: " + str(np.mean(precision_score(RFCprediction, y_test, average=None))))
print("Precision of the ETC model for this data: " + str(np.mean(precision_score(ETCprediction, y_test, average=None))))
print("Precision of the GNB model for this data: " + str(np.mean(precision_score(GNBprediction, y_test, average=None))))
print("Precision of the BNB model for this data: " + str(np.mean(precision_score(BNBprediction, y_test, average=None))))
print("Precision of the LRG model for this data: " + str(np.mean(precision_score(LRGprediction, y_test, average=None))))
print("Precision of the LDA model for this data: " + str(np.mean(precision_score(LDAprediction, y_test, average=None))))
print("Precision of the MLP model for this data: " + str(np.mean(precision_score(MLPprediction, y_test, average=None))))



#print("Recall of the SVM model for this data: " + str(np.mean(recall_score(SVMprediction, y_test, average=None))))
print("Recall of the KNN model for this data: " + str(np.mean(recall_score(KNNprediction, y_test, average=None))))
#print("Recall of the RNN model for this data: " + str(np.mean(recall_score(RNNprediction, y_test, average=None))))
print("Recall of the DTC model for this data: " + str(np.mean(recall_score(DTCprediction, y_test, average=None))))
print("Recall of the RFC model for this data: " + str(np.mean(recall_score(RFCprediction, y_test, average=None))))
print("Recall of the ETC model for this data: " + str(np.mean(recall_score(ETCprediction, y_test, average=None))))
print("Recall of the GNB model for this data: " + str(np.mean(recall_score(GNBprediction, y_test, average=None))))
print("Recall of the BNB model for this data: " + str(np.mean(recall_score(BNBprediction, y_test, average=None))))
print("Recall of the LRG model for this data: " + str(np.mean(recall_score(LRGprediction, y_test, average=None))))
print("Recall of the LDA model for this data: " + str(np.mean(recall_score(LDAprediction, y_test, average=None))))
print("Recall of the MLP model for this data: " + str(np.mean(recall_score(MLPprediction, y_test, average=None))))


#print("F1_score of the SVM model for this data: " + str(np.mean(f1_score(SVMprediction, y_test, average=None))))
print("F1_score of the KNN model for this data: " + str(np.mean(f1_score(KNNprediction, y_test, average=None))))
#print("F1_score of the RNN model for this data: " + str(np.mean(f1_score(RNNprediction, y_test, average=None))))
print("F1_score of the DTC model for this data: " + str(np.mean(f1_score(DTCprediction, y_test, average=None))))
print("F1_score of the RFC model for this data: " + str(np.mean(f1_score(RFCprediction, y_test, average=None))))
print("F1_score of the ETC model for this data: " + str(np.mean(f1_score(ETCprediction, y_test, average=None))))
print("F1_score of the GNB model for this data: " + str(np.mean(f1_score(GNBprediction, y_test, average=None))))
print("F1_score of the BNB model for this data: " + str(np.mean(f1_score(BNBprediction, y_test, average=None))))
print("F1_score of the LRG model for this data: " + str(np.mean(f1_score(LRGprediction, y_test, average=None))))
print("F1_score of the LDA model for this data: " + str(np.mean(f1_score(LDAprediction, y_test, average=None))))
print("F1_score of the MLP model for this data: " + str(np.mean(f1_score(MLPprediction, y_test, average=None))))


#print("Jaccard_score of the SVM model for this data: " + str(np.mean(jaccard_score(SVMprediction, y_test, average=None))))
print("Jaccard_score of the KNN model for this data: " + str(np.mean(jaccard_score(KNNprediction, y_test, average=None))))
#print("Jaccard_score of the RNN model for this data: " + str(np.mean(jaccard_score(RNNprediction, y_test, average=None))))
print("Jaccard_score of the DTC model for this data: " + str(np.mean(jaccard_score(DTCprediction, y_test, average=None))))
print("Jaccard_score of the RFC model for this data: " + str(np.mean(jaccard_score(RFCprediction, y_test, average=None))))
print("Jaccard_score of the ETC model for this data: " + str(np.mean(jaccard_score(ETCprediction, y_test, average=None))))
print("Jaccard_score of the GNB model for this data: " + str(np.mean(jaccard_score(GNBprediction, y_test, average=None))))
print("Jaccard_score of the BNB model for this data: " + str(np.mean(jaccard_score(BNBprediction, y_test, average=None))))
print("Jaccard_score of the LRG model for this data: " + str(np.mean(jaccard_score(LRGprediction, y_test, average=None))))
print("Jaccard_score of the LDA model for this data: " + str(np.mean(jaccard_score(LDAprediction, y_test, average=None))))
print("Jaccard_score of the MLP model for this data: " + str(np.mean(jaccard_score(MLPprediction, y_test, average=None))))


#print("Kohen_Kappa_score of the SVM model for this data: " + str(np.mean(cohen_kappa_score(SVMprediction, y_test))))
print("Kohen_Kappa_score of the KNN model for this data: " + str(np.mean(cohen_kappa_score(KNNprediction, y_test))))
#print("Kohen_Kappa_score of the RNN model for this data: " + str(np.mean(cohen_kappa_score(RNNprediction, y_test))))
print("Kohen_Kappa_score of the DTC model for this data: " + str(np.mean(cohen_kappa_score(DTCprediction, y_test))))
print("Kohen_Kappa_score of the RFC model for this data: " + str(np.mean(cohen_kappa_score(RFCprediction, y_test))))
print("Kohen_Kappa_score of the ETC model for this data: " + str(np.mean(cohen_kappa_score(ETCprediction, y_test))))
print("Kohen_Kappa_score of the GNB model for this data: " + str(np.mean(cohen_kappa_score(GNBprediction, y_test))))
print("Kohen_Kappa_score of the BNB model for this data: " + str(np.mean(cohen_kappa_score(BNBprediction, y_test))))
print("Kohen_Kappa_score of the LRG model for this data: " + str(np.mean(cohen_kappa_score(LRGprediction, y_test))))
print("Kohen_Kappa_score of the LDA model for this data: " + str(np.mean(cohen_kappa_score(LDAprediction, y_test))))
print("Kohen_Kappa_score of the MLP model for this data: " + str(np.mean(cohen_kappa_score(MLPprediction, y_test))))


#print("Hamming_Loss of the SVM model for this data: " + str(np.mean(hamming_loss(SVMprediction, y_test))))
print("Hamming_Loss of the KNN model for this data: " + str(np.mean(hamming_loss(KNNprediction, y_test))))
#print("Hamming_Loss of the RNN model for this data: " + str(np.mean(hamming_loss(RNNprediction, y_test))))
print("Hamming_Loss of the DTC model for this data: " + str(np.mean(hamming_loss(DTCprediction, y_test))))
print("Hamming_Loss of the RFC model for this data: " + str(np.mean(hamming_loss(RFCprediction, y_test))))
print("Hamming_Loss of the ETC model for this data: " + str(np.mean(hamming_loss(ETCprediction, y_test))))
print("Hamming_Loss of the GNB model for this data: " + str(np.mean(hamming_loss(GNBprediction, y_test))))
print("Hamming_Loss of the BNB model for this data: " + str(np.mean(hamming_loss(BNBprediction, y_test))))
print("Hamming_Loss of the LRG model for this data: " + str(np.mean(hamming_loss(LRGprediction, y_test))))
print("Hamming_Loss of the LDA model for this data: " + str(np.mean(hamming_loss(LDAprediction, y_test))))
print("Hamming_Loss of the MLP model for this data: " + str(np.mean(hamming_loss(MLPprediction, y_test))))


#print("Matthews_corrcoef of the SVM model for this data: " + str(np.mean(matthews_corrcoef(SVMprediction, y_test))))
print("Matthews_corrcoef of the KNN model for this data: " + str(np.mean(matthews_corrcoef(KNNprediction, y_test))))
#print("Matthews_corrcoef of the RNN model for this data: " + str(np.mean(matthews_corrcoef(RNNprediction, y_test))))
print("Matthews_corrcoef of the DTC model for this data: " + str(np.mean(matthews_corrcoef(DTCprediction, y_test))))
print("Matthews_corrcoef of the RFC model for this data: " + str(np.mean(matthews_corrcoef(RFCprediction, y_test))))
print("Matthews_corrcoef of the ETC model for this data: " + str(np.mean(matthews_corrcoef(ETCprediction, y_test))))
print("Matthews_corrcoef of the GNB model for this data: " + str(np.mean(matthews_corrcoef(GNBprediction, y_test))))
print("Matthews_corrcoef of the BNB model for this data: " + str(np.mean(matthews_corrcoef(BNBprediction, y_test))))
print("Matthews_corrcoef of the LRG model for this data: " + str(np.mean(matthews_corrcoef(LRGprediction, y_test))))
print("Matthews_corrcoef of the LDA model for this data: " + str(np.mean(matthews_corrcoef(LDAprediction, y_test))))
print("Matthews_corrcoef of the MLP model for this data: " + str(np.mean(matthews_corrcoef(MLPprediction, y_test))))
# Out:
# /home/subhrangshu/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Decomposition time 65029.99496459961
# /home/subhrangshu/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Train time for KNN: 330.2900791168213
# Train time for DTC: 1439.4404888153076
# /tmp/ipykernel_32279/1544385508.py:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFCmodel = RFCmodel.fit(X_train, y_train)
# Train time for RFC: 40699.42927360535
# ...
